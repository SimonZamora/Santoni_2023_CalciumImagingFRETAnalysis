# %% [markdown]
# ### This notebook import images associated with each nucleus, correct for bleedthrough and compute NFRET pixel by pixel. Distribution of average NFRET value are computed over all nucleus in a biological replicate and a label low-mid-high is attributed to each nucleus.

# %%
import pandas as pd
import numpy as np
from skimage import io
import pandas as pd
import os
import numpy as np
import pandas as pd
import pickle


#General Variables 

#bleedthrough values used for correction 

bt_D=0.67 # signal bleed-through (SBT) of the donor in the SE channel
bt_A=0.84 #SBT of the acceptor in the SE channel
bt_RCamp=0.26 #SBT of the RCamp in the SE channel

# %%
# Path to the directory containing FRET files output from FIJI (position of each ROI in the original image and classification from QuPath)
path_fret = r'C:\Users\SimonZ\Desktop\Code\graffproject\FRETRec\fijioutput'

# Path to the directory containing TIFF files for each cell
path_to_tiffs= r'C:\Users\SimonZ\Desktop\Code\graffproject\FRETRec\rois'

# List to store paths of FRET files
list_of_fret_files = []

# Walk through the directory structure to find FRET files
for root, dirs, files in os.walk(path_fret):
    for file in files:
        # Get the full path of the file
        file_path = os.path.join(root, file)
        
        # Append the file path to the list
        list_of_fret_files.append(file_path)

# Print the paths of FRET files
for file_path in list_of_fret_files:
    print(file_path)
# Out:
# C:\Users\SimonZ\Desktop\Code\graffproject\FRETRec\fijioutput\01.06_H3_Well3.csv
# C:\Users\SimonZ\Desktop\Code\graffproject\FRETRec\fijioutput\31.05_H3_Well5.csv
# C:\Users\SimonZ\Desktop\Code\graffproject\FRETRec\fijioutput\31.05_H3_Well6.csv

# %%
# List to store FRET cell data
fret_cells = []

# Iterate over each file (one file by recording, output from FIJI)
for file_path in list_of_fret_files:
    # Extract the name of the file
    name = os.path.splitext(os.path.basename(file_path))[0]
    
    # Read the data from the CSV file
    data = pd.read_csv(file_path)

    nb_frame = data.max()['Frame']
    nb_channel = data.max()['Ch']
    nb_cells = int(len(data)/(nb_frame*nb_channel))

    # Iterate over each cell in the data
    for i in range(nb_cells):
        
        # Check if the cell is classified as positive by QuPath
        if 'Positive' in data.iloc[i]["Label"]:     
            # Extract X and Y coordinates of the cell
            x_y_coordinates = np.array([data.iloc[i]['X'], data.iloc[i]['Y']])
            
            # Create a dictionary containing cell information
            cell_data = {
                'Label': name + '_' + str(i), # Label attributed by FIJI
                'ROI_Number': data.iloc[i].iloc[0], # Number of the ROI tiff file
                "Coordinates": x_y_coordinates  # X and Y coordinates of the cell
            }
            
            # Append the cell data to the list of FRET data
            fret_cells.append(cell_data)

# Output the extracted FRET data
for fret_data in fret_cells:
    print(fret_data)
# Out:
# {'Label': '01.06_H3_Well3_1', 'ROI_Number': 2, 'Coordinates': array([409.535, 500.357])}
# {'Label': '01.06_H3_Well3_2', 'ROI_Number': 3, 'Coordinates': array([409.133, 401.363])}
# {'Label': '01.06_H3_Well3_3', 'ROI_Number': 4, 'Coordinates': array([571.123, 351.699])}
# {'Label': '01.06_H3_Well3_4', 'ROI_Number': 5, 'Coordinates': array([ 41.712, 365.882])}
# {'Label': '01.06_H3_Well3_5', 'ROI_Number': 6, 'Coordinates': array([516.186, 401.747])}
# {'Label': '01.06_H3_Well3_6', 'ROI_Number': 7, 'Coordinates': array([490.481, 395.921])}
# {'Label': '01.06_H3_Well3_8', 'ROI_Number': 9, 'Coordinates': array([425.105, 148.616])}
# {'Label': '01.06_H3_Well3_9', 'ROI_Number': 10, 'Coordinates': array([308.069, 192.033])}
# {'Label': '01.06_H3_Well3_10', 'ROI_Number': 11, 'Coordinates': array([616.264, 395.313])}
# {'Label': '01.06_H3_Well3_11', 'ROI_Number': 12, 'Coordinates': array([320.827, 186.102])}
# {'Label': '01.06_H3_Well3_12', 'ROI_Number': 13, 'Coordinates': array([148.514, 374.905])}
# {'Label': '01.06_H3_Well3_13', 'ROI_Number': 14, 'Coordinates': array([617.459, 315.515])}
# {'Label': '01.06_H3_Well3_14', 'ROI_Number': 15, 'Coordinates': array([ 75.013, 224.238])}
# {'Label': '01.06_H3_Well3_15', 'ROI_Number': 16, 'Coordinates': array([389.869, 163.118])}
# {'Label': '01.06_H3_Well3_16', 'ROI_Number': 17, 'Coordinates': array([305.417,  85.34 ])}
# {'Label': '01.06_H3_Well3_17', 'ROI_Number': 18, 'Coordinates': array([500.726, 328.4  ])}
# {'Label': '01.06_H3_Well3_18', 'ROI_Number': 19, 'Coordinates': array([95.614, 35.862])}
# {'Label': '01.06_H3_Well3_19', 'ROI_Number': 20, 'Coordinates': array([206.373, 583.888])}
# {'Label': '01.06_H3_Well3_20', 'ROI_Number': 21, 'Coordinates': array([276.465, 273.787])}
# {'Label': '01.06_H3_Well3_21', 'ROI_Number': 22, 'Coordinates': array([390.059, 247.271])}
# {'Label': '01.06_H3_Well3_22', 'ROI_Number': 23, 'Coordinates': array([176.881, 339.736])}
# {'Label': '01.06_H3_Well3_24', 'ROI_Number': 25, 'Coordinates': array([215.042, 363.142])}
# {'Label': '01.06_H3_Well3_25', 'ROI_Number': 26, 'Coordinates': array([37.027, 41.859])}
# {'Label': '01.06_H3_Well3_26', 'ROI_Number': 27, 'Coordinates': array([ 3.791, 95.766])}
# {'Label': '01.06_H3_Well3_27', 'ROI_Number': 28, 'Coordinates': array([490.237, 275.32 ])}
# {'Label': '01.06_H3_Well3_28', 'ROI_Number': 29, 'Coordinates': array([ 30.987, 155.271])}
# {'Label': '01.06_H3_Well3_29', 'ROI_Number': 30, 'Coordinates': array([282.384, 441.219])}
# {'Label': '01.06_H3_Well3_30', 'ROI_Number': 31, 'Coordinates': array([576.555, 339.631])}
# {'Label': '01.06_H3_Well3_31', 'ROI_Number': 32, 'Coordinates': array([109.516, 381.113])}
# {'Label': '01.06_H3_Well3_33', 'ROI_Number': 34, 'Coordinates': array([535.927, 313.307])}
# {'Label': '01.06_H3_Well3_34', 'ROI_Number': 35, 'Coordinates': array([239.062,   4.006])}
# {'Label': '01.06_H3_Well3_35', 'ROI_Number': 36, 'Coordinates': array([467.514,  46.48 ])}
# {'Label': '01.06_H3_Well3_36', 'ROI_Number': 37, 'Coordinates': array([565.117, 580.823])}
# {'Label': '01.06_H3_Well3_37', 'ROI_Number': 38, 'Coordinates': array([401.351,  46.044])}
# {'Label': '01.06_H3_Well3_38', 'ROI_Number': 39, 'Coordinates': array([396.842,  88.882])}
# {'Label': '01.06_H3_Well3_39', 'ROI_Number': 40, 'Coordinates': array([545.013, 474.293])}
# {'Label': '01.06_H3_Well3_40', 'ROI_Number': 41, 'Coordinates': array([  2.435, 403.675])}
# {'Label': '01.06_H3_Well3_41', 'ROI_Number': 42, 'Coordinates': array([394.788, 430.386])}
# {'Label': '01.06_H3_Well3_42', 'ROI_Number': 43, 'Coordinates': array([ 84.137, 106.168])}
# {'Label': '01.06_H3_Well3_43', 'ROI_Number': 44, 'Coordinates': array([ 59.057, 518.518])}
# {'Label': '01.06_H3_Well3_45', 'ROI_Number': 46, 'Coordinates': array([ 28.782, 476.982])}
# {'Label': '01.06_H3_Well3_48', 'ROI_Number': 49, 'Coordinates': array([590.087, 155.888])}
# {'Label': '01.06_H3_Well3_51', 'ROI_Number': 52, 'Coordinates': array([224.549,  81.89 ])}
# {'Label': '01.06_H3_Well3_52', 'ROI_Number': 53, 'Coordinates': array([ 41.274, 573.696])}
# {'Label': '01.06_H3_Well3_53', 'ROI_Number': 54, 'Coordinates': array([574.438, 384.777])}
# {'Label': '01.06_H3_Well3_54', 'ROI_Number': 55, 'Coordinates': array([307.373,  64.48 ])}
# {'Label': '01.06_H3_Well3_55', 'ROI_Number': 56, 'Coordinates': array([114.532, 111.411])}
# {'Label': '01.06_H3_Well3_57', 'ROI_Number': 58, 'Coordinates': array([303.389, 378.079])}
# {'Label': '01.06_H3_Well3_58', 'ROI_Number': 59, 'Coordinates': array([286.251,  39.079])}
# {'Label': '01.06_H3_Well3_59', 'ROI_Number': 60, 'Coordinates': array([267.898, 569.447])}
# {'Label': '01.06_H3_Well3_60', 'ROI_Number': 61, 'Coordinates': array([567.32 , 160.578])}
# {'Label': '01.06_H3_Well3_61', 'ROI_Number': 62, 'Coordinates': array([189.302, 457.783])}
# {'Label': '01.06_H3_Well3_62', 'ROI_Number': 63, 'Coordinates': array([243.594, 608.256])}
# {'Label': '01.06_H3_Well3_63', 'ROI_Number': 64, 'Coordinates': array([130.887, 404.576])}
# {'Label': '01.06_H3_Well3_64', 'ROI_Number': 65, 'Coordinates': array([131.71 , 181.422])}
# {'Label': '01.06_H3_Well3_65', 'ROI_Number': 66, 'Coordinates': array([132.204,  65.201])}
# {'Label': '01.06_H3_Well3_66', 'ROI_Number': 67, 'Coordinates': array([129.348, 246.21 ])}
# {'Label': '01.06_H3_Well3_67', 'ROI_Number': 68, 'Coordinates': array([317.692, 409.251])}
# {'Label': '01.06_H3_Well3_68', 'ROI_Number': 69, 'Coordinates': array([ 41.121, 263.081])}
# {'Label': '01.06_H3_Well3_69', 'ROI_Number': 70, 'Coordinates': array([407.419, 175.57 ])}
# {'Label': '01.06_H3_Well3_70', 'ROI_Number': 71, 'Coordinates': array([145.329, 589.893])}
# {'Label': '01.06_H3_Well3_71', 'ROI_Number': 72, 'Coordinates': array([ 95.016, 356.586])}
# {'Label': '01.06_H3_Well3_72', 'ROI_Number': 73, 'Coordinates': array([171.306, 254.915])}
# {'Label': '01.06_H3_Well3_73', 'ROI_Number': 74, 'Coordinates': array([362.441, 481.023])}
# {'Label': '01.06_H3_Well3_75', 'ROI_Number': 76, 'Coordinates': array([564.976, 473.785])}
# {'Label': '01.06_H3_Well3_76', 'ROI_Number': 77, 'Coordinates': array([369.17 , 245.714])}
# {'Label': '01.06_H3_Well3_77', 'ROI_Number': 78, 'Coordinates': array([407.616, 420.428])}
# {'Label': '01.06_H3_Well3_78', 'ROI_Number': 79, 'Coordinates': array([520.635, 584.631])}
# {'Label': '01.06_H3_Well3_79', 'ROI_Number': 80, 'Coordinates': array([381.966, 267.499])}
# {'Label': '01.06_H3_Well3_80', 'ROI_Number': 81, 'Coordinates': array([24.752, 54.862])}
# {'Label': '01.06_H3_Well3_81', 'ROI_Number': 82, 'Coordinates': array([180.336, 290.7  ])}
# {'Label': '01.06_H3_Well3_82', 'ROI_Number': 83, 'Coordinates': array([606.601, 381.052])}
# {'Label': '01.06_H3_Well3_83', 'ROI_Number': 84, 'Coordinates': array([  3.76 , 115.944])}
# {'Label': '01.06_H3_Well3_84', 'ROI_Number': 85, 'Coordinates': array([455.447, 161.826])}
# {'Label': '01.06_H3_Well3_85', 'ROI_Number': 86, 'Coordinates': array([464.827,  22.669])}
# {'Label': '01.06_H3_Well3_87', 'ROI_Number': 88, 'Coordinates': array([516.238, 232.474])}
# {'Label': '01.06_H3_Well3_88', 'ROI_Number': 89, 'Coordinates': array([431.15 , 527.311])}
# {'Label': '01.06_H3_Well3_91', 'ROI_Number': 92, 'Coordinates': array([537.641, 181.535])}
# {'Label': '01.06_H3_Well3_92', 'ROI_Number': 93, 'Coordinates': array([ 69.507, 449.782])}
# {'Label': '01.06_H3_Well3_93', 'ROI_Number': 94, 'Coordinates': array([376.58 , 441.098])}
# {'Label': '01.06_H3_Well3_94', 'ROI_Number': 95, 'Coordinates': array([449.935, 391.249])}
# {'Label': '01.06_H3_Well3_95', 'ROI_Number': 96, 'Coordinates': array([91.364, 89.598])}
# {'Label': '01.06_H3_Well3_96', 'ROI_Number': 97, 'Coordinates': array([318.2  , 558.783])}
# {'Label': '01.06_H3_Well3_97', 'ROI_Number': 98, 'Coordinates': array([561.092,  37.73 ])}
# {'Label': '01.06_H3_Well3_98', 'ROI_Number': 99, 'Coordinates': array([276.951, 204.419])}
# {'Label': '01.06_H3_Well3_99', 'ROI_Number': 100, 'Coordinates': array([525.534, 202.106])}
# {'Label': '01.06_H3_Well3_100', 'ROI_Number': 101, 'Coordinates': array([155.35, 267.41])}
# {'Label': '01.06_H3_Well3_101', 'ROI_Number': 102, 'Coordinates': array([475.842, 522.309])}
# {'Label': '01.06_H3_Well3_102', 'ROI_Number': 103, 'Coordinates': array([379.856, 461.331])}
# {'Label': '01.06_H3_Well3_103', 'ROI_Number': 104, 'Coordinates': array([ 24.82 , 493.389])}
# {'Label': '01.06_H3_Well3_104', 'ROI_Number': 105, 'Coordinates': array([586.785, 211.483])}
# {'Label': '01.06_H3_Well3_105', 'ROI_Number': 106, 'Coordinates': array([424.002, 544.32 ])}
# {'Label': '01.06_H3_Well3_108', 'ROI_Number': 109, 'Coordinates': array([317.522, 535.154])}
# {'Label': '01.06_H3_Well3_109', 'ROI_Number': 110, 'Coordinates': array([315.44 ,  33.467])}
# {'Label': '01.06_H3_Well3_110', 'ROI_Number': 111, 'Coordinates': array([265.596, 243.802])}
# {'Label': '01.06_H3_Well3_111', 'ROI_Number': 112, 'Coordinates': array([284.253, 100.644])}
# {'Label': '01.06_H3_Well3_115', 'ROI_Number': 116, 'Coordinates': array([164.557, 118.606])}
# {'Label': '31.05_H3_Well5_0', 'ROI_Number': 1, 'Coordinates': array([324.178, 589.497])}
# {'Label': '31.05_H3_Well5_1', 'ROI_Number': 2, 'Coordinates': array([347.614, 349.641])}
# {'Label': '31.05_H3_Well5_2', 'ROI_Number': 3, 'Coordinates': array([ 50.502, 459.27 ])}
# {'Label': '31.05_H3_Well5_3', 'ROI_Number': 4, 'Coordinates': array([248.051,  65.675])}
# {'Label': '31.05_H3_Well5_4', 'ROI_Number': 5, 'Coordinates': array([269.835, 243.25 ])}
# {'Label': '31.05_H3_Well5_6', 'ROI_Number': 7, 'Coordinates': array([340.908, 388.262])}
# {'Label': '31.05_H3_Well5_8', 'ROI_Number': 9, 'Coordinates': array([219.857, 459.523])}
# {'Label': '31.05_H3_Well5_9', 'ROI_Number': 10, 'Coordinates': array([464.685, 375.784])}
# {'Label': '31.05_H3_Well5_10', 'ROI_Number': 11, 'Coordinates': array([599.643,  15.184])}
# {'Label': '31.05_H3_Well5_11', 'ROI_Number': 12, 'Coordinates': array([191.769,  74.156])}
# {'Label': '31.05_H3_Well5_13', 'ROI_Number': 14, 'Coordinates': array([71.528, 74.41 ])}
# {'Label': '31.05_H3_Well5_14', 'ROI_Number': 15, 'Coordinates': array([566.369,  13.471])}
# {'Label': '31.05_H3_Well5_19', 'ROI_Number': 20, 'Coordinates': array([202.406, 296.395])}
# {'Label': '31.05_H3_Well5_20', 'ROI_Number': 21, 'Coordinates': array([435.296, 173.29 ])}
# {'Label': '31.05_H3_Well5_21', 'ROI_Number': 22, 'Coordinates': array([114.44 , 299.465])}
# {'Label': '31.05_H3_Well5_23', 'ROI_Number': 24, 'Coordinates': array([471.672, 300.481])}
# {'Label': '31.05_H3_Well5_25', 'ROI_Number': 26, 'Coordinates': array([145.547,  15.942])}
# {'Label': '31.05_H3_Well5_26', 'ROI_Number': 27, 'Coordinates': array([511.397, 176.31 ])}
# {'Label': '31.05_H3_Well5_27', 'ROI_Number': 28, 'Coordinates': array([110.871, 423.168])}
# {'Label': '31.05_H3_Well5_28', 'ROI_Number': 29, 'Coordinates': array([366.885, 367.785])}
# {'Label': '31.05_H3_Well5_29', 'ROI_Number': 30, 'Coordinates': array([96.502, 25.009])}
# {'Label': '31.05_H3_Well5_30', 'ROI_Number': 31, 'Coordinates': array([381.241, 173.388])}
# {'Label': '31.05_H3_Well5_37', 'ROI_Number': 38, 'Coordinates': array([131.513, 428.638])}
# {'Label': '31.05_H3_Well5_39', 'ROI_Number': 40, 'Coordinates': array([507.74 , 571.948])}
# {'Label': '31.05_H3_Well5_41', 'ROI_Number': 42, 'Coordinates': array([ 74.788, 341.496])}
# {'Label': '31.05_H3_Well5_46', 'ROI_Number': 47, 'Coordinates': array([497.173, 209.864])}
# {'Label': '31.05_H3_Well5_47', 'ROI_Number': 48, 'Coordinates': array([611.818, 369.475])}
# {'Label': '31.05_H3_Well5_49', 'ROI_Number': 50, 'Coordinates': array([118.938, 133.222])}
# {'Label': '31.05_H3_Well5_51', 'ROI_Number': 52, 'Coordinates': array([438.744, 609.863])}
# {'Label': '31.05_H3_Well5_52', 'ROI_Number': 53, 'Coordinates': array([139.092, 343.764])}
# {'Label': '31.05_H3_Well5_54', 'ROI_Number': 55, 'Coordinates': array([285.918, 613.601])}
# {'Label': '31.05_H3_Well5_56', 'ROI_Number': 57, 'Coordinates': array([60.618, 33.933])}
# {'Label': '31.05_H3_Well5_58', 'ROI_Number': 59, 'Coordinates': array([114.097,  46.259])}
# {'Label': '31.05_H3_Well5_60', 'ROI_Number': 61, 'Coordinates': array([ 32.333, 268.378])}
# {'Label': '31.05_H3_Well5_61', 'ROI_Number': 62, 'Coordinates': array([ 52.867, 413.26 ])}
# {'Label': '31.05_H3_Well5_62', 'ROI_Number': 63, 'Coordinates': array([116.123, 183.601])}
# {'Label': '31.05_H3_Well5_65', 'ROI_Number': 66, 'Coordinates': array([121.061, 227.729])}
# {'Label': '31.05_H3_Well5_69', 'ROI_Number': 70, 'Coordinates': array([155.459, 591.584])}
# {'Label': '31.05_H3_Well5_76', 'ROI_Number': 77, 'Coordinates': array([417.57 , 230.905])}
# {'Label': '31.05_H3_Well5_78', 'ROI_Number': 79, 'Coordinates': array([166.704,  41.421])}
# {'Label': '31.05_H3_Well5_80', 'ROI_Number': 81, 'Coordinates': array([356.784, 358.381])}
# {'Label': '31.05_H3_Well5_83', 'ROI_Number': 84, 'Coordinates': array([357.322, 601.03 ])}
# {'Label': '31.05_H3_Well5_85', 'ROI_Number': 86, 'Coordinates': array([413.607, 124.032])}
# {'Label': '31.05_H3_Well5_87', 'ROI_Number': 88, 'Coordinates': array([534.044, 584.738])}
# {'Label': '31.05_H3_Well5_89', 'ROI_Number': 90, 'Coordinates': array([442.285, 355.58 ])}
# {'Label': '31.05_H3_Well5_90', 'ROI_Number': 91, 'Coordinates': array([487.454, 565.123])}
# {'Label': '31.05_H3_Well5_94', 'ROI_Number': 95, 'Coordinates': array([523.222, 471.815])}
# {'Label': '31.05_H3_Well5_95', 'ROI_Number': 96, 'Coordinates': array([38.767, 38.372])}
# {'Label': '31.05_H3_Well5_97', 'ROI_Number': 98, 'Coordinates': array([312.185, 321.516])}
# {'Label': '31.05_H3_Well5_101', 'ROI_Number': 102, 'Coordinates': array([476.682, 212.614])}
# {'Label': '31.05_H3_Well5_102', 'ROI_Number': 103, 'Coordinates': array([ 18.944, 339.292])}
# {'Label': '31.05_H3_Well5_104', 'ROI_Number': 105, 'Coordinates': array([384.344, 365.276])}
# {'Label': '31.05_H3_Well5_106', 'ROI_Number': 107, 'Coordinates': array([246.046, 321.604])}
# {'Label': '31.05_H3_Well5_107', 'ROI_Number': 108, 'Coordinates': array([567.714, 459.184])}
# {'Label': '31.05_H3_Well5_108', 'ROI_Number': 109, 'Coordinates': array([524.067,  53.486])}
# {'Label': '31.05_H3_Well5_109', 'ROI_Number': 110, 'Coordinates': array([510.146, 482.455])}
# {'Label': '31.05_H3_Well5_111', 'ROI_Number': 112, 'Coordinates': array([ 63.086, 151.999])}
# {'Label': '31.05_H3_Well5_112', 'ROI_Number': 113, 'Coordinates': array([ 20.167, 374.459])}
# {'Label': '31.05_H3_Well5_114', 'ROI_Number': 115, 'Coordinates': array([118.663, 252.355])}
# {'Label': '31.05_H3_Well5_115', 'ROI_Number': 116, 'Coordinates': array([127.928, 173.7  ])}
# {'Label': '31.05_H3_Well5_116', 'ROI_Number': 117, 'Coordinates': array([60.273, 79.732])}
# {'Label': '31.05_H3_Well5_123', 'ROI_Number': 124, 'Coordinates': array([444.924, 272.315])}
# {'Label': '31.05_H3_Well5_124', 'ROI_Number': 125, 'Coordinates': array([338.32 , 590.895])}
# {'Label': '31.05_H3_Well5_126', 'ROI_Number': 127, 'Coordinates': array([ 71.236, 529.984])}
# {'Label': '31.05_H3_Well5_128', 'ROI_Number': 129, 'Coordinates': array([168.998,  77.826])}
# {'Label': '31.05_H3_Well5_133', 'ROI_Number': 134, 'Coordinates': array([308.915, 605.305])}
# {'Label': '31.05_H3_Well5_134', 'ROI_Number': 135, 'Coordinates': array([165.54, 261.72])}
# {'Label': '31.05_H3_Well5_135', 'ROI_Number': 136, 'Coordinates': array([146.015, 190.979])}
# {'Label': '31.05_H3_Well5_136', 'ROI_Number': 137, 'Coordinates': array([433.569, 396.039])}
# {'Label': '31.05_H3_Well5_137', 'ROI_Number': 138, 'Coordinates': array([424.659,  73.174])}
# {'Label': '31.05_H3_Well5_143', 'ROI_Number': 144, 'Coordinates': array([ 88.954, 261.757])}
# {'Label': '31.05_H3_Well5_144', 'ROI_Number': 145, 'Coordinates': array([269.927, 262.725])}
# {'Label': '31.05_H3_Well6_0', 'ROI_Number': 1, 'Coordinates': array([134.861, 520.232])}
# {'Label': '31.05_H3_Well6_1', 'ROI_Number': 2, 'Coordinates': array([143.516, 138.703])}
# {'Label': '31.05_H3_Well6_8', 'ROI_Number': 9, 'Coordinates': array([283.049, 169.758])}
# {'Label': '31.05_H3_Well6_11', 'ROI_Number': 12, 'Coordinates': array([471.032,  42.299])}
# {'Label': '31.05_H3_Well6_16', 'ROI_Number': 17, 'Coordinates': array([187.234, 610.626])}
# {'Label': '31.05_H3_Well6_17', 'ROI_Number': 18, 'Coordinates': array([229.076, 529.159])}
# {'Label': '31.05_H3_Well6_18', 'ROI_Number': 19, 'Coordinates': array([136.392,  12.606])}
# {'Label': '31.05_H3_Well6_20', 'ROI_Number': 21, 'Coordinates': array([536.101, 482.684])}
# {'Label': '31.05_H3_Well6_21', 'ROI_Number': 22, 'Coordinates': array([ 54.93 , 269.173])}
# {'Label': '31.05_H3_Well6_22', 'ROI_Number': 23, 'Coordinates': array([601.128, 403.43 ])}
# {'Label': '31.05_H3_Well6_23', 'ROI_Number': 24, 'Coordinates': array([505.404, 232.281])}
# {'Label': '31.05_H3_Well6_24', 'ROI_Number': 25, 'Coordinates': array([271.028, 397.405])}
# {'Label': '31.05_H3_Well6_25', 'ROI_Number': 26, 'Coordinates': array([371.646, 283.318])}
# {'Label': '31.05_H3_Well6_30', 'ROI_Number': 31, 'Coordinates': array([358.356, 130.298])}
# {'Label': '31.05_H3_Well6_34', 'ROI_Number': 35, 'Coordinates': array([332.209, 433.689])}
# {'Label': '31.05_H3_Well6_35', 'ROI_Number': 36, 'Coordinates': array([72.876,  4.393])}
# {'Label': '31.05_H3_Well6_36', 'ROI_Number': 37, 'Coordinates': array([473.674, 280.792])}
# {'Label': '31.05_H3_Well6_40', 'ROI_Number': 41, 'Coordinates': array([445.834, 393.67 ])}
# {'Label': '31.05_H3_Well6_43', 'ROI_Number': 44, 'Coordinates': array([120.781,  16.164])}
# {'Label': '31.05_H3_Well6_44', 'ROI_Number': 45, 'Coordinates': array([311.877, 261.254])}
# {'Label': '31.05_H3_Well6_46', 'ROI_Number': 47, 'Coordinates': array([296.318, 113.059])}
# {'Label': '31.05_H3_Well6_49', 'ROI_Number': 50, 'Coordinates': array([40.356, 16.008])}
# {'Label': '31.05_H3_Well6_50', 'ROI_Number': 51, 'Coordinates': array([369.297, 145.308])}
# {'Label': '31.05_H3_Well6_52', 'ROI_Number': 53, 'Coordinates': array([ 58.014, 477.375])}
# {'Label': '31.05_H3_Well6_53', 'ROI_Number': 54, 'Coordinates': array([581.433, 326.11 ])}
# {'Label': '31.05_H3_Well6_54', 'ROI_Number': 55, 'Coordinates': array([286.587, 325.148])}
# {'Label': '31.05_H3_Well6_55', 'ROI_Number': 56, 'Coordinates': array([576.932, 270.604])}
# {'Label': '31.05_H3_Well6_58', 'ROI_Number': 59, 'Coordinates': array([443.939, 575.475])}
# {'Label': '31.05_H3_Well6_59', 'ROI_Number': 60, 'Coordinates': array([615.102, 418.498])}
# {'Label': '31.05_H3_Well6_60', 'ROI_Number': 61, 'Coordinates': array([222.054, 267.315])}
# {'Label': '31.05_H3_Well6_61', 'ROI_Number': 62, 'Coordinates': array([590.304, 179.085])}
# {'Label': '31.05_H3_Well6_62', 'ROI_Number': 63, 'Coordinates': array([ 50.168, 177.083])}
# {'Label': '31.05_H3_Well6_63', 'ROI_Number': 64, 'Coordinates': array([483.968, 213.282])}
# {'Label': '31.05_H3_Well6_65', 'ROI_Number': 66, 'Coordinates': array([104.994, 264.554])}
# {'Label': '31.05_H3_Well6_66', 'ROI_Number': 67, 'Coordinates': array([319.483, 603.479])}
# {'Label': '31.05_H3_Well6_68', 'ROI_Number': 69, 'Coordinates': array([317.189, 246.908])}
# {'Label': '31.05_H3_Well6_71', 'ROI_Number': 72, 'Coordinates': array([176.721, 256.486])}
# {'Label': '31.05_H3_Well6_73', 'ROI_Number': 74, 'Coordinates': array([521.155, 457.167])}
# {'Label': '31.05_H3_Well6_74', 'ROI_Number': 75, 'Coordinates': array([273.354,  46.605])}
# {'Label': '31.05_H3_Well6_77', 'ROI_Number': 78, 'Coordinates': array([264.673, 495.746])}
# {'Label': '31.05_H3_Well6_78', 'ROI_Number': 79, 'Coordinates': array([380.886, 444.865])}
# {'Label': '31.05_H3_Well6_81', 'ROI_Number': 82, 'Coordinates': array([42.278, 66.257])}
# {'Label': '31.05_H3_Well6_82', 'ROI_Number': 83, 'Coordinates': array([278.77 , 287.515])}
# {'Label': '31.05_H3_Well6_84', 'ROI_Number': 85, 'Coordinates': array([43.244, 48.965])}
# {'Label': '31.05_H3_Well6_87', 'ROI_Number': 88, 'Coordinates': array([408.369, 618.338])}
# {'Label': '31.05_H3_Well6_89', 'ROI_Number': 90, 'Coordinates': array([243.183,  24.65 ])}
# {'Label': '31.05_H3_Well6_90', 'ROI_Number': 91, 'Coordinates': array([432.569, 235.25 ])}
# {'Label': '31.05_H3_Well6_93', 'ROI_Number': 94, 'Coordinates': array([370.77 , 198.392])}
# {'Label': '31.05_H3_Well6_94', 'ROI_Number': 95, 'Coordinates': array([115.166, 257.074])}
# {'Label': '31.05_H3_Well6_95', 'ROI_Number': 96, 'Coordinates': array([391.726,  55.53 ])}
# {'Label': '31.05_H3_Well6_97', 'ROI_Number': 98, 'Coordinates': array([ 64.328, 243.127])}
# {'Label': '31.05_H3_Well6_100', 'ROI_Number': 101, 'Coordinates': array([458.557, 575.794])}
# {'Label': '31.05_H3_Well6_101', 'ROI_Number': 102, 'Coordinates': array([565.99 , 515.725])}
# {'Label': '31.05_H3_Well6_103', 'ROI_Number': 104, 'Coordinates': array([75.593, 24.183])}
# {'Label': '31.05_H3_Well6_106', 'ROI_Number': 107, 'Coordinates': array([380.776, 602.358])}
# {'Label': '31.05_H3_Well6_109', 'ROI_Number': 110, 'Coordinates': array([149.311, 511.215])}
# {'Label': '31.05_H3_Well6_111', 'ROI_Number': 112, 'Coordinates': array([ 8.969, 40.129])}
# {'Label': '31.05_H3_Well6_114', 'ROI_Number': 115, 'Coordinates': array([215.592, 407.754])}
# {'Label': '31.05_H3_Well6_115', 'ROI_Number': 116, 'Coordinates': array([261.111, 415.41 ])}
# {'Label': '31.05_H3_Well6_116', 'ROI_Number': 117, 'Coordinates': array([288.508, 504.936])}
# {'Label': '31.05_H3_Well6_117', 'ROI_Number': 118, 'Coordinates': array([ 16.721, 508.836])}
# {'Label': '31.05_H3_Well6_120', 'ROI_Number': 121, 'Coordinates': array([55.632, 93.985])}
# {'Label': '31.05_H3_Well6_122', 'ROI_Number': 123, 'Coordinates': array([532.591, 428.032])}
# {'Label': '31.05_H3_Well6_124', 'ROI_Number': 125, 'Coordinates': array([324.857, 119.127])}
# {'Label': '31.05_H3_Well6_126', 'ROI_Number': 127, 'Coordinates': array([187.147, 534.714])}
# {'Label': '31.05_H3_Well6_127', 'ROI_Number': 128, 'Coordinates': array([201.122, 610.166])}
# {'Label': '31.05_H3_Well6_128', 'ROI_Number': 129, 'Coordinates': array([272.267, 206.855])}
# {'Label': '31.05_H3_Well6_129', 'ROI_Number': 130, 'Coordinates': array([115.304, 159.545])}
# {'Label': '31.05_H3_Well6_130', 'ROI_Number': 131, 'Coordinates': array([375.132, 332.578])}
# {'Label': '31.05_H3_Well6_131', 'ROI_Number': 132, 'Coordinates': array([67.893, 98.196])}
# {'Label': '31.05_H3_Well6_132', 'ROI_Number': 133, 'Coordinates': array([ 34.223, 318.312])}
# {'Label': '31.05_H3_Well6_138', 'ROI_Number': 139, 'Coordinates': array([10.316, 15.065])}
# {'Label': '31.05_H3_Well6_139', 'ROI_Number': 140, 'Coordinates': array([166.398, 303.961])}
# {'Label': '31.05_H3_Well6_140', 'ROI_Number': 141, 'Coordinates': array([198.757, 570.6  ])}
# {'Label': '31.05_H3_Well6_148', 'ROI_Number': 149, 'Coordinates': array([564.331, 449.714])}
# {'Label': '31.05_H3_Well6_150', 'ROI_Number': 151, 'Coordinates': array([ 13.848, 266.792])}
# {'Label': '31.05_H3_Well6_151', 'ROI_Number': 152, 'Coordinates': array([371.73 , 135.334])}

# %%
def return_tiff(cell, path_to_tiffs):
    """
    Return the TIFF image data for a given cell.

    Parameters:
        cell (dict): A dictionary containing information about the cell.
        path_to_tiffs (str): The path to the directory containing TIFF files.

    Returns:
        numpy.ndarray: The TIFF image data for the specified cell.
    """
    # Split the cell label to extract recording name and ROI number
    label_parts = cell["Label"].split('_')
    recording_name = '_'.join(label_parts[:3])  # Extract recording name
    roi_number = cell["ROI_Number"]  # Extract ROI number
    
    # Construct the path to the TIFF file using recording name and ROI number
    tiff_path = f"{path_to_tiffs}/{recording_name}/{recording_name}_ROI{roi_number}.tif"
    
    # Read the TIFF file
    tiff = io.imread(tiff_path)

    # fig, ax = plt.subplots(nrows=1, ncols=6,figsize=(5, 10)) #to plot in case
    # ax[0].imshow(tiff[0,:,:]) #Exc-Donor and Em-Donor 
    # ax[1].imshow(tiff[1,:,:]) #Exc-Donor and Em-Acceptor 
    # ax[2].imshow(tiff[2,:,:]) # Transmitted light
    # ax[3].imshow(tiff[3,:,:]) #Exc-Acceptor and Em-Acceptor 
    # ax[4].imshow(tiff[4,:,:]) #Exc-RCamp and Em-RCamp 
    # ax[5].imshow(tiff[6,:,:]) # Each pixel has the value of the number of the ROI

    # # Return the TIFF data
    return tiff

# %%
def build_cell_pxl_info(cell, path_to_tiffs, channel_D=0, channel_SE=1, channel_A=3, channel_RCamp=4):
    """
    Build information about pixels associated with a cell's ROI from a TIFF file.

    Parameters:
        cell (dict): A dictionary containing information about the cell.
        path_to_tiffs (str): The path to the directory containing TIFF files.
        channel_D (int): Channel index for intensity in the donor channel.
        channel_SE (int): Channel index for intensity in the FRET channel.
        channel_A (int): Channel index for intensity in the acceptor channel.
        channel_RCamp (int): Channel index for intensity in the RCamp channel.

    Returns:
        pd.DataFrame: DataFrame containing pixel information for the cell's ROI.
    """
    # Retrieve TIFF data for the cell
    tiff_file = return_tiff(cell, path_to_tiffs)
    nb_roi = cell["ROI_Number"]
    
    # Lists to store pixel information for each channel
    I_donor = []  # Exc-Donor and Em-Donor
    I_SE = []  # Exc-Donor and Em-Acceptor
    I_acceptor = []  # Exc-Acceptor and Em-Acceptor
    I_RCamp = []  # Exc-RCamp and Em-RCamp

    I_outside_ROI_acceptor = [] #store value of the pixel outside the ROI to compute the background value 
    dim = tiff_file.shape

    tot_area = 0
    area_with_signal = 0
    
    # Iterate over all pixels in the TIFF file
    for i in range(dim[1]):
        for j in range(dim[2]):
            # Check if the pixel is part of the ROI
            if tiff_file[-1, i, j] == nb_roi:
                tot_area += 1
                
                # Check if the pixel has values for all channels
                if (not np.isnan(tiff_file[channel_D, i, j])) and \
                   (not np.isnan(tiff_file[channel_SE, i, j])) and \
                   (not np.isnan(tiff_file[channel_A, i, j])) and \
                   (not np.isnan(tiff_file[channel_RCamp, i, j])):

                    # Store pixel values for each channel
                    I_donor.append(tiff_file[channel_D, i, j] + 1)
                    I_SE.append(tiff_file[channel_SE, i, j] + 1)
                    I_acceptor.append(tiff_file[channel_A, i, j] + 1)
                    I_RCamp.append(tiff_file[channel_RCamp, i, j] + 1)
                    area_with_signal += 1
            else:
                #If not in the ROI, store value of the acceptor channel
                I_outside_ROI_acceptor.append(tiff_file[channel_A, i, j] + 1)

    # Create a DataFrame with pixel information
    df = {'donor': I_donor, 'SE': I_SE, 'acceptor': I_acceptor, 'RCamp': I_RCamp, 'ROI_area': tot_area, 'area_with_signal': area_with_signal,'background_acceptor':np.mean(I_outside_ROI_acceptor)}
    ROI_info = pd.DataFrame(df)
    return ROI_info

# %%
def compute_NFRET(cell, bt_D_D, bt_A_A, bt_RCamp):
    """
    Compute the normalized FRET (NFRET) value for a given cell.

    Parameters:
        cell (dict): A dictionary containing information about the cell.
        bt_D_D (float): Bleedthrough value for the donor channel.
        bt_A_A (float): Bleedthrough value for the acceptor channel.
        bt_RCamp (float): Bleedthrough value for the RCamp channel.

    Returns:
        float: The computed normalized FRET (NFRET) value.
    """
    # Extract pixel intensities from the cell data
    I_donor = cell["Pixelval"]["donor"]     # Pixel intensity of donor channel
    I_SE = cell["Pixelval"]["SE"]           # Pixel intensity of sensitize emission (SE) channel
    I_acceptor = cell["Pixelval"]["acceptor"]   # Pixel intensity of acceptor channel
    I_RCamp = cell["Pixelval"]["RCamp"]     # Pixel intensity of RCamp channel
    
    # Compute normalized FRET (NFRET) using the provided bleedthrough values
    NFRET = (I_SE - I_donor * bt_D_D - I_acceptor * bt_A_A - I_RCamp * bt_RCamp) / I_acceptor
    
    return NFRET

# %%
def compute_mean_intensity(cell):
    """
    Compute the mean intensity values for each channel and the mean NFRET value for a given cell.

    Parameters:
        cell (dict): A dictionary containing information about the cell.

    Returns:
        dict: A dictionary containing the mean intensity values for each channel and the mean NFRET value.
    """
    # Extract pixel intensities and NFRET value from the cell data
    I_D = cell["Pixelval"]["donor"]      # All ROI pixel intensity of donor channel
    I_SE = cell["Pixelval"]["SE"]        # All ROI pixel intensity of ensitize emission (SE) channel
    I_A = cell["Pixelval"]["acceptor"]   # All ROI pixel intensity of acceptor channel
    I_RCamp = cell["Pixelval"]["RCamp"]  # All ROI pixel intensity of RCamp channel
    NFRET = cell["Pixelval"]["NFRET"]    # All ROI pixel intensity of normalized FRET (NFRET) value
    
    # Compute the mean intensity values for each channel and the mean NFRET value
    mean_intensity = {
        "donor": np.mean(I_D),
        "SE": np.mean(I_SE),
        "acceptor": np.mean(I_A),
        "RCamp": np.mean(I_RCamp),
        "NFRET": np.mean(NFRET)
    }
    
    return mean_intensity

# %% [markdown]
# # Extract the information from the Tiff file

# %%
# Compute the NFRET for each cell
for cell in fret_cells:
    cell["Pixelval"]= build_cell_pxl_info(cell, path_to_tiffs)
    cell["Pixelval"]["NFRET"]= compute_NFRET(cell, bt_D, bt_A, bt_RCamp)
    cell["meanval"] = compute_mean_intensity(cell)

# %% [markdown]
# ### We exclude cell showing saturation in more than 10% of their pixel and/or showing unsufficient signal in either I_D or I_A

# %%
def sufficient_signal(cell, contrast_value_I_A):
    """
    Check if the signal in a cell is sufficient for analysis based on given criteria.

    Parameters:
        cell (dict): A dictionary containing information about the cell.
        contrast_value_I_A (float): Contrast value for the acceptor channel.

    Returns:
        bool: True if the signal is sufficient, False otherwise.
    """
    # Initialize flag for signal sufficiency
    sufficient_signal = True
    
    # Check conditions for signal sufficiency
    if contrast_value_I_A < 1.8 and cell["meanval"]["acceptor"] < 20:  # Low contrast and low intensity in acceptor channel  -> This is a nucleus without signal in the acceptor channel
        sufficient_signal = False
    if contrast_value_I_A >= 1.8 and cell["meanval"]["acceptor"] < 8:  # High contrast but low intensity in acceptor channel -> This is a nucleus without signal in the acceptor channel
        sufficient_signal = False
    if cell["meanval"]["donor"] < 20 and cell["meanval"]["NFRET"] < 2:  # Low intensity in donor and NFRET channels -> This is a nucleus without signal in the donor or NFRET probably a false positive
        sufficient_signal = False
    
    return sufficient_signal

# %%
good_cells = []

for cell in fret_cells:
    #Check if the number of pixel with signal (non-saturated pixel) in a given ROI is at least 90% of the total area of the ROI
    if cell["Pixelval"]["area_with_signal"][0] > 0.9 * cell["Pixelval"]["ROI_area"][0]:
        contrast_value_I_A = cell["meanval"]["acceptor"] / np.mean(cell["Pixelval"]["background_acceptor"])

        if sufficient_signal(cell, contrast_value_I_A):
            good_cells.append(cell)

print("Total number of cells:", len(fret_cells))
print("Total number of cells showing good signal:", len(good_cells))
# Out:
# Total number of cells: 246
# Total number of cells showing good signal: 125

# %% [markdown]
# ## Attribute low-mid-high class depending on the NFRET value

# %%
# List to store NFRET values of good cells
NFRET_values = []

# Iterate over good cells to collect NFRET values
for cell in good_cells:
    NFRET_values.append(cell["meanval"]["NFRET"])

# Calculate mean and standard deviation of NFRET values
mean_NFRET = np.mean(NFRET_values)
std_FRET = np.std(NFRET_values)

# Iterate over good cells to classify them based on NFRET values
for cell in good_cells:
    # Initialize cell class as 'mid'
    cell["class"] = 'Mid'
    
    # Check if NFRET value is below the low threshold
    if cell["meanval"]["NFRET"] < mean_NFRET - std_FRET / 2:
        cell["class"] = 'Low'
    
    # Check if NFRET value is above the high threshold
    if cell["meanval"]["NFRET"] >= mean_NFRET + std_FRET / 2:
        cell["class"] = 'High'

# %% [markdown]
# ## Save the result in a pickle file to use in the 2_CombineFRETCA.ipynb jupyter notebook for further analysis

# %%
# Save to pickle file
with open('FRETgood_cells.pkl', 'wb') as pickle_file:
    pickle.dump(good_cells, pickle_file)
